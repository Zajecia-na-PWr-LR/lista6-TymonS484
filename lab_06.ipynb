# %% [markdown]
# ## Część 1

# %% [markdown]
# ### Zadanie 1.1

# %%
import sklearn.datasets
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)
pd.set_option('display.width', 0)
pd.set_option('display.max_colwidth', None)

Speed_dating = sklearn.datasets.fetch_openml(data_id = 40536, as_frame = True)
df = Speed_dating.frame



df['match'] = pd.to_numeric(df['match'], errors='coerce')

df.describe(include = 'all')
# Out:
#        has_null         wave gender          age        age_o        d_age  \
# count      8378  8378.000000   8378  8283.000000  8274.000000  8378.000000
# unique        2          NaN      2          NaN          NaN          NaN
# top           1          NaN   male          NaN          NaN          NaN
# freq       7330          NaN   4194          NaN          NaN          NaN
# mean        NaN    11.350919    NaN    26.358928    26.364999     4.185605
# std         NaN     5.995903    NaN     3.566763     3.563648     4.596171
# min         NaN     1.000000    NaN    18.000000    18.000000     0.000000
# 25%         NaN     7.000000    NaN    24.000000    24.000000     1.000000
# 50%         NaN    11.000000    NaN    26.000000    26.000000     3.000000
# 75%         NaN    15.000000    NaN    28.000000    28.000000     5.000000
# max         NaN    21.000000    NaN    55.000000    55.000000    37.000000
#
#        d_d_age                         race                       race_o  \
# count     8378                         8315                         8305
# unique       4                            5                            5
# top      [2-3]  European/Caucasian-American  European/Caucasian-American
# freq      2406                         4727                         4722
# mean       NaN                          NaN                          NaN
# std        NaN                          NaN                          NaN
# min        NaN                          NaN                          NaN
# 25%        NaN                          NaN                          NaN
# 50%        NaN                          NaN                          NaN
# 75%        NaN                          NaN                          NaN
# max        NaN                          NaN                          NaN
#
#        samerace  importance_same_race  importance_same_religion  \
# count      8378           8299.000000               8299.000000
# unique        2                   NaN                       NaN
# top           0                   NaN                       NaN
# freq       5062                   NaN                       NaN
# mean        NaN              3.784793                  3.651645
# std         NaN              2.845708                  2.805237
# min         NaN              0.000000                  1.000000
# 25%         NaN              1.000000                  1.000000
# 50%         NaN              3.000000                  3.000000
# 75%         NaN              6.000000                  6.000000
# max         NaN             10.000000                 10.000000
#
#        d_importance_same_race d_importance_same_religion     field  \
# count                    8378                       8378      8315
# unique                      3                          3       259
# top                     [2-5]                      [0-1]  Business
# freq                     3104                       3111       521
# mean                      NaN                        NaN       NaN
# std                       NaN                        NaN       NaN
# min                       NaN                        NaN       NaN
# 25%                       NaN                        NaN       NaN
# 50%                       NaN                        NaN       NaN
# 75%                       NaN                        NaN       NaN
# max                       NaN                        NaN       NaN
#
#         pref_o_attractive  pref_o_sincere  pref_o_intelligence  pref_o_funny  \
# count         8289.000000     8289.000000          8289.000000   8280.000000
# unique                NaN             NaN                  NaN           NaN
# top                   NaN             NaN                  NaN           NaN
# freq                  NaN             NaN                  NaN           NaN
# mean            22.495347       17.396867            20.270759     17.459714
# std             12.569802        7.044003             6.782895      6.085526
# min              0.000000        0.000000             0.000000      0.000000
# 25%             15.000000       15.000000            17.390000     15.000000
# 50%             20.000000       18.370000            20.000000     18.000000
# 75%             25.000000       20.000000            23.810000     20.000000
# max            100.000000       60.000000            50.000000     50.000000
#
#         pref_o_ambitious  pref_o_shared_interests d_pref_o_attractive  \
# count        8271.000000              8249.000000                8378
# unique               NaN                      NaN                   3
# top                  NaN                      NaN            [21-100]
# freq                 NaN                      NaN                3010
# mean           10.685375                11.845930                 NaN
# std             6.126544                 6.362746                 NaN
# min             0.000000                 0.000000                 NaN
# 25%             5.000000                 9.520000                 NaN
# 50%            10.000000                10.640000                 NaN
# 75%            15.000000                16.000000                 NaN
# max            53.000000                30.000000                 NaN
#
#        d_pref_o_sincere d_pref_o_intelligence d_pref_o_funny  \
# count              8378                  8378           8378
# unique                3                     3              3
# top             [16-20]               [16-20]        [16-20]
# freq               3820                  4272           3870
# mean                NaN                   NaN            NaN
# std                 NaN                   NaN            NaN
# min                 NaN                   NaN            NaN
# 25%                 NaN                   NaN            NaN
# 50%                 NaN                   NaN            NaN
# 75%                 NaN                   NaN            NaN
# max                 NaN                   NaN            NaN
#
#        d_pref_o_ambitious d_pref_o_shared_interests  attractive_o  \
# count                8378                      8378   8166.000000
# unique                  3                         3           NaN
# top                [0-15]                    [0-15]           NaN
# freq                 6680                      6085           NaN
# mean                  NaN                       NaN      6.190411
# std                   NaN                       NaN      1.950305
# min                   NaN                       NaN      0.000000
# 25%                   NaN                       NaN      5.000000
# 50%                   NaN                       NaN      6.000000
# 75%                   NaN                       NaN      8.000000
# max                   NaN                       NaN     10.500000
#
#           sinsere_o  intelligence_o      funny_o   ambitous_o  \
# count   8091.000000     8072.000000  8018.000000  7656.000000
# unique          NaN             NaN          NaN          NaN
# top             NaN             NaN          NaN          NaN
# freq            NaN             NaN          NaN          NaN
# mean       7.175256        7.369301     6.400599     6.778409
# std        1.740575        1.550501     1.954078     1.794080
# min        0.000000        0.000000     0.000000     0.000000
# 25%        6.000000        6.000000     5.000000     6.000000
# 50%        7.000000        7.000000     7.000000     7.000000
# 75%        8.000000        8.000000     8.000000     8.000000
# max       10.000000       10.000000    11.000000    10.000000
#
#         shared_interests_o d_attractive_o d_sinsere_o d_intelligence_o  \
# count          7302.000000           8378        8378             8378
# unique                 NaN              3           3                3
# top                    NaN          [6-8]       [6-8]            [6-8]
# freq                   NaN           4537        5192             5379
# mean              5.474870            NaN         NaN              NaN
# std               2.156163            NaN         NaN              NaN
# min               0.000000            NaN         NaN              NaN
# 25%               4.000000            NaN         NaN              NaN
# 50%               6.000000            NaN         NaN              NaN
# 75%               7.000000            NaN         NaN              NaN
# max              10.000000            NaN         NaN              NaN
#
#        d_funny_o d_ambitous_o d_shared_interests_o  attractive_important  \
# count       8378         8378                 8378           8299.000000
# unique         3            3                    3                   NaN
# top        [6-8]        [6-8]                [0-5]                   NaN
# freq        4645         4613                 4690                   NaN
# mean         NaN          NaN                  NaN             22.514632
# std          NaN          NaN                  NaN             12.587674
# min          NaN          NaN                  NaN              0.000000
# 25%          NaN          NaN                  NaN             15.000000
# 50%          NaN          NaN                  NaN             20.000000
# 75%          NaN          NaN                  NaN             25.000000
# max          NaN          NaN                  NaN            100.000000
#
#         sincere_important  intellicence_important  funny_important  \
# count         8299.000000             8299.000000      8289.000000
# unique                NaN                     NaN              NaN
# top                   NaN                     NaN              NaN
# freq                  NaN                     NaN              NaN
# mean            17.396389               20.265613        17.457043
# std              7.046700                6.783003         6.085239
# min              0.000000                0.000000         0.000000
# 25%             15.000000               17.390000        15.000000
# 50%             18.180000               20.000000        18.000000
# 75%             20.000000               23.810000        20.000000
# max             60.000000               50.000000        50.000000
#
#         ambtition_important  shared_interests_important  \
# count           8279.000000                 8257.000000
# unique                  NaN                         NaN
# top                     NaN                         NaN
# freq                    NaN                         NaN
# mean              10.682539                   11.845111
# std                6.124888                    6.362154
# min                0.000000                    0.000000
# 25%                5.000000                    9.520000
# 50%               10.000000                   10.640000
# 75%               15.000000                   16.000000
# max               53.000000                   30.000000
#
#        d_attractive_important d_sincere_important d_intellicence_important  \
# count                    8378                8378                     8378
# unique                      3                   3                        3
# top                  [21-100]             [16-20]                  [16-20]
# freq                     3019                3821                     4276
# mean                      NaN                 NaN                      NaN
# std                       NaN                 NaN                      NaN
# min                       NaN                 NaN                      NaN
# 25%                       NaN                 NaN                      NaN
# 50%                       NaN                 NaN                      NaN
# 75%                       NaN                 NaN                      NaN
# max                       NaN                 NaN                      NaN
#
#        d_funny_important d_ambtition_important d_shared_interests_important  \
# count               8378                  8378                         8378
# unique                 3                     3                            3
# top              [16-20]                [0-15]                       [0-15]
# freq                3874                  6680                         6083
# mean                 NaN                   NaN                          NaN
# std                  NaN                   NaN                          NaN
# min                  NaN                   NaN                          NaN
# 25%                  NaN                   NaN                          NaN
# 50%                  NaN                   NaN                          NaN
# 75%                  NaN                   NaN                          NaN
# max                  NaN                   NaN                          NaN
#
#          attractive      sincere  intelligence        funny     ambition  \
# count   8273.000000  8273.000000   8273.000000  8273.000000  8273.000000
# unique          NaN          NaN           NaN          NaN          NaN
# top             NaN          NaN           NaN          NaN          NaN
# freq            NaN          NaN           NaN          NaN          NaN
# mean       7.084733     8.294935      7.704460     8.403965     7.578388
# std        1.395783     1.407460      1.564321     1.076608     1.778315
# min        2.000000     2.000000      2.000000     3.000000     2.000000
# 25%        6.000000     8.000000      7.000000     8.000000     7.000000
# 50%        7.000000     8.000000      8.000000     8.000000     8.000000
# 75%        8.000000     9.000000      9.000000     9.000000     9.000000
# max       10.000000    10.000000     10.000000    10.000000    10.000000
#
#        d_attractive d_sincere d_intelligence d_funny d_ambition  \
# count          8378      8378           8378    8378       8378
# unique            3         3              3       3          3
# top           [6-8]    [9-10]          [6-8]   [6-8]      [6-8]
# freq           6231      4084           4929    4244       4407
# mean            NaN       NaN            NaN     NaN        NaN
# std             NaN       NaN            NaN     NaN        NaN
# min             NaN       NaN            NaN     NaN        NaN
# 25%             NaN       NaN            NaN     NaN        NaN
# 50%             NaN       NaN            NaN     NaN        NaN
# 75%             NaN       NaN            NaN     NaN        NaN
# max             NaN       NaN            NaN     NaN        NaN
#
#         attractive_partner  sincere_partner  intelligence_partner  \
# count          8176.000000      8101.000000           8082.000000
# unique                 NaN              NaN                   NaN
# top                    NaN              NaN                   NaN
# freq                   NaN              NaN                   NaN
# mean              6.189995         7.175164              7.368597
# std               1.950169         1.740315              1.550453
# min               0.000000         0.000000              0.000000
# 25%               5.000000         6.000000              6.000000
# 50%               6.000000         7.000000              7.000000
# 75%               8.000000         8.000000              8.000000
# max              10.000000        10.000000             10.000000
#
#         funny_partner  ambition_partner  shared_interests_partner  \
# count     8028.000000       7666.000000               7311.000000
# unique            NaN               NaN                       NaN
# top               NaN               NaN                       NaN
# freq              NaN               NaN                       NaN
# mean         6.400598          6.777524                  5.474559
# std          1.953702          1.794055                  2.156363
# min          0.000000          0.000000                  0.000000
# 25%          5.000000          6.000000                  4.000000
# 50%          7.000000          7.000000                  6.000000
# 75%          8.000000          8.000000                  7.000000
# max         10.000000         10.000000                 10.000000
#
#        d_attractive_partner d_sincere_partner d_intelligence_partner  \
# count                  8378              8378                   8378
# unique                    3                 3                      3
# top                   [6-8]             [6-8]                  [6-8]
# freq                   4545              5198                   5385
# mean                    NaN               NaN                    NaN
# std                     NaN               NaN                    NaN
# min                     NaN               NaN                    NaN
# 25%                     NaN               NaN                    NaN
# 50%                     NaN               NaN                    NaN
# 75%                     NaN               NaN                    NaN
# max                     NaN               NaN                    NaN
#
#        d_funny_partner d_ambition_partner d_shared_interests_partner  \
# count             8378               8378                       8378
# unique               3                  3                          3
# top              [6-8]              [6-8]                      [0-5]
# freq              4651               4618                       4686
# mean               NaN                NaN                        NaN
# std                NaN                NaN                        NaN
# min                NaN                NaN                        NaN
# 25%                NaN                NaN                        NaN
# 50%                NaN                NaN                        NaN
# 75%                NaN                NaN                        NaN
# max                NaN                NaN                        NaN
#
#              sports     tvsports     exercise       dining      museums  \
# count   8299.000000  8299.000000  8299.000000  8299.000000  8299.000000
# unique          NaN          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN          NaN
# mean       6.425232     4.575491     6.245813     7.783829     6.985781
# std        2.619024     2.801874     2.418858     1.754868     2.052232
# min        1.000000     1.000000     1.000000     1.000000     0.000000
# 25%        4.000000     2.000000     5.000000     7.000000     6.000000
# 50%        7.000000     4.000000     6.000000     8.000000     7.000000
# 75%        9.000000     7.000000     8.000000     9.000000     9.000000
# max       10.000000    10.000000    10.000000    10.000000    10.000000
#
#                 art       hiking       gaming     clubbing      reading  \
# count   8299.000000  8299.000000  8299.000000  8299.000000  8299.000000
# unique          NaN          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN          NaN
# mean       6.714544     5.737077     3.881191     5.745993     7.678515
# std        2.263407     2.570207     2.620507     2.502218     2.006565
# min        0.000000     0.000000     0.000000     0.000000     1.000000
# 25%        5.000000     4.000000     2.000000     4.000000     7.000000
# 50%        7.000000     6.000000     3.000000     6.000000     8.000000
# 75%        8.000000     8.000000     6.000000     8.000000     9.000000
# max       10.000000    10.000000    14.000000    10.000000    13.000000
#
#                  tv      theater       movies     concerts        music  \
# count   8299.000000  8299.000000  8299.000000  8299.000000  8299.000000
# unique          NaN          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN          NaN
# mean       5.304133     6.776118     7.919629     6.825401     7.851066
# std        2.529135     2.235152     1.700927     2.156283     1.791827
# min        1.000000     0.000000     0.000000     0.000000     1.000000
# 25%        3.000000     5.000000     7.000000     5.000000     7.000000
# 50%        6.000000     7.000000     8.000000     7.000000     8.000000
# 75%        7.000000     9.000000     9.000000     8.000000     9.000000
# max       10.000000    10.000000    10.000000    10.000000    10.000000
#
#            shopping         yoga d_sports d_tvsports d_exercise d_dining  \
# count   8299.000000  8299.000000     8378       8378       8378     8378
# unique          NaN          NaN        3          3          3        3
# top             NaN          NaN    [6-8]      [0-5]      [6-8]    [6-8]
# freq            NaN          NaN     3239       5219       3718     4147
# mean       5.631281     4.339197      NaN        NaN        NaN      NaN
# std        2.608913     2.717612      NaN        NaN        NaN      NaN
# min        1.000000     0.000000      NaN        NaN        NaN      NaN
# 25%        4.000000     2.000000      NaN        NaN        NaN      NaN
# 50%        6.000000     4.000000      NaN        NaN        NaN      NaN
# 75%        8.000000     7.000000      NaN        NaN        NaN      NaN
# max       10.000000    10.000000      NaN        NaN        NaN      NaN
#
#        d_museums  d_art d_hiking d_gaming d_clubbing d_reading   d_tv  \
# count       8378   8378     8378     8378       8378      8378   8378
# unique         3      3        3        3          3         3      3
# top        [6-8]  [6-8]    [0-5]    [0-5]      [6-8]     [6-8]  [0-5]
# freq        4299   3994     3751     6109       3831      3659   4158
# mean         NaN    NaN      NaN      NaN        NaN       NaN    NaN
# std          NaN    NaN      NaN      NaN        NaN       NaN    NaN
# min          NaN    NaN      NaN      NaN        NaN       NaN    NaN
# 25%          NaN    NaN      NaN      NaN        NaN       NaN    NaN
# 50%          NaN    NaN      NaN      NaN        NaN       NaN    NaN
# 75%          NaN    NaN      NaN      NaN        NaN       NaN    NaN
# max          NaN    NaN      NaN      NaN        NaN       NaN    NaN
#
#        d_theater d_movies d_concerts d_music d_shopping d_yoga  \
# count       8378     8378       8378    8378       8378   8378
# unique         3        3          3       3          3      3
# top        [6-8]    [6-8]      [6-8]   [6-8]      [0-5]  [0-5]
# freq        3906     4152       4179    3941       3975   5444
# mean         NaN      NaN        NaN     NaN        NaN    NaN
# std          NaN      NaN        NaN     NaN        NaN    NaN
# min          NaN      NaN        NaN     NaN        NaN    NaN
# 25%          NaN      NaN        NaN     NaN        NaN    NaN
# 50%          NaN      NaN        NaN     NaN        NaN    NaN
# 75%          NaN      NaN        NaN     NaN        NaN    NaN
# max          NaN      NaN        NaN     NaN        NaN    NaN
#
#         interests_correlate d_interests_correlate  \
# count           8220.000000                  8378
# unique                  NaN                     3
# top                     NaN              [0-0.33]
# freq                    NaN                  3063
# mean               0.196010                   NaN
# std                0.303539                   NaN
# min               -0.830000                   NaN
# 25%               -0.020000                   NaN
# 50%                0.210000                   NaN
# 75%                0.430000                   NaN
# max                0.910000                   NaN
#
#         expected_happy_with_sd_people  expected_num_interested_in_me  \
# count                     8277.000000                    1800.000000
# unique                            NaN                            NaN
# top                               NaN                            NaN
# freq                              NaN                            NaN
# mean                         5.534131                       5.570556
# std                          1.734059                       4.762569
# min                          1.000000                       0.000000
# 25%                          5.000000                       2.000000
# 50%                          6.000000                       4.000000
# 75%                          7.000000                       8.000000
# max                         10.000000                      20.000000
#
#         expected_num_matches d_expected_happy_with_sd_people  \
# count            7205.000000                            8378
# unique                   NaN                               3
# top                      NaN                           [5-6]
# freq                     NaN                            4036
# mean                3.207814                             NaN
# std                 2.444813                             NaN
# min                 0.000000                             NaN
# 25%                 2.000000                             NaN
# 50%                 3.000000                             NaN
# 75%                 4.000000                             NaN
# max                18.000000                             NaN
#
#        d_expected_num_interested_in_me d_expected_num_matches         like  \
# count                             8378                   8378  8138.000000
# unique                               3                      3          NaN
# top                              [0-3]                  [0-2]          NaN
# freq                              7346                   4514          NaN
# mean                               NaN                    NaN     6.134087
# std                                NaN                    NaN     1.841285
# min                                NaN                    NaN     0.000000
# 25%                                NaN                    NaN     5.000000
# 50%                                NaN                    NaN     6.000000
# 75%                                NaN                    NaN     7.000000
# max                                NaN                    NaN    10.000000
#
#         guess_prob_liked d_like d_guess_prob_liked          met        match
# count        8069.000000   8378               8378  8003.000000  8378.000000
# unique               NaN      3                  3          NaN          NaN
# top                  NaN  [6-8]              [5-6]          NaN          NaN
# freq                 NaN   4827               3199          NaN          NaN
# mean            5.207523    NaN                NaN     0.049856     0.164717
# std             2.129565    NaN                NaN     0.282168     0.370947
# min             0.000000    NaN                NaN     0.000000     0.000000
# 25%             4.000000    NaN                NaN     0.000000     0.000000
# 50%             5.000000    NaN                NaN     0.000000     0.000000
# 75%             7.000000    NaN                NaN     0.000000     0.000000
# max            10.000000    NaN                NaN     8.000000     1.000000

# %%
df.head()
# Out:
#   has_null  wave  gender   age  age_o  d_age d_d_age  \
# 0        0     1  female  21.0   27.0      6   [4-6]
# 1        0     1  female  21.0   22.0      1   [0-1]
# 2        1     1  female  21.0   22.0      1   [0-1]
# 3        0     1  female  21.0   23.0      2   [2-3]
# 4        0     1  female  21.0   24.0      3   [2-3]
#
#                                     race  \
# 0  Asian/Pacific Islander/Asian-American
# 1  Asian/Pacific Islander/Asian-American
# 2  Asian/Pacific Islander/Asian-American
# 3  Asian/Pacific Islander/Asian-American
# 4  Asian/Pacific Islander/Asian-American
#
#                                   race_o samerace  importance_same_race  \
# 0            European/Caucasian-American        0                   2.0
# 1            European/Caucasian-American        0                   2.0
# 2  Asian/Pacific Islander/Asian-American        1                   2.0
# 3            European/Caucasian-American        0                   2.0
# 4               Latino/Hispanic American        0                   2.0
#
#    importance_same_religion d_importance_same_race d_importance_same_religion  \
# 0                       4.0                  [2-5]                      [2-5]
# 1                       4.0                  [2-5]                      [2-5]
# 2                       4.0                  [2-5]                      [2-5]
# 3                       4.0                  [2-5]                      [2-5]
# 4                       4.0                  [2-5]                      [2-5]
#
#   field  pref_o_attractive  pref_o_sincere  pref_o_intelligence  pref_o_funny  \
# 0   Law               35.0            20.0                 20.0          20.0
# 1   Law               60.0             0.0                  0.0          40.0
# 2   Law               19.0            18.0                 19.0          18.0
# 3   Law               30.0             5.0                 15.0          40.0
# 4   Law               30.0            10.0                 20.0          10.0
#
#    pref_o_ambitious  pref_o_shared_interests d_pref_o_attractive  \
# 0               0.0                      5.0            [21-100]
# 1               0.0                      0.0            [21-100]
# 2              14.0                     12.0             [16-20]
# 3               5.0                      5.0            [21-100]
# 4              10.0                     20.0            [21-100]
#
#   d_pref_o_sincere d_pref_o_intelligence d_pref_o_funny d_pref_o_ambitious  \
# 0          [16-20]               [16-20]        [16-20]             [0-15]
# 1           [0-15]                [0-15]       [21-100]             [0-15]
# 2          [16-20]               [16-20]        [16-20]             [0-15]
# 3           [0-15]                [0-15]       [21-100]             [0-15]
# 4           [0-15]               [16-20]         [0-15]             [0-15]
#
#   d_pref_o_shared_interests  attractive_o  sinsere_o  intelligence_o  funny_o  \
# 0                    [0-15]           6.0        8.0             8.0      8.0
# 1                    [0-15]           7.0        8.0            10.0      7.0
# 2                    [0-15]          10.0       10.0            10.0     10.0
# 3                    [0-15]           7.0        8.0             9.0      8.0
# 4                   [16-20]           8.0        7.0             9.0      6.0
#
#    ambitous_o  shared_interests_o d_attractive_o d_sinsere_o d_intelligence_o  \
# 0         8.0                 6.0          [6-8]       [6-8]            [6-8]
# 1         7.0                 5.0          [6-8]       [6-8]           [9-10]
# 2        10.0                10.0         [9-10]      [9-10]           [9-10]
# 3         9.0                 8.0          [6-8]       [6-8]           [9-10]
# 4         9.0                 7.0          [6-8]       [6-8]           [9-10]
#
#   d_funny_o d_ambitous_o d_shared_interests_o  attractive_important  \
# 0     [6-8]        [6-8]                [6-8]                  15.0
# 1     [6-8]        [6-8]                [0-5]                  15.0
# 2    [9-10]       [9-10]               [9-10]                  15.0
# 3     [6-8]       [9-10]                [6-8]                  15.0
# 4     [6-8]       [9-10]                [6-8]                  15.0
#
#    sincere_important  intellicence_important  funny_important  \
# 0               20.0                    20.0             15.0
# 1               20.0                    20.0             15.0
# 2               20.0                    20.0             15.0
# 3               20.0                    20.0             15.0
# 4               20.0                    20.0             15.0
#
#    ambtition_important  shared_interests_important d_attractive_important  \
# 0                 15.0                        15.0                 [0-15]
# 1                 15.0                        15.0                 [0-15]
# 2                 15.0                        15.0                 [0-15]
# 3                 15.0                        15.0                 [0-15]
# 4                 15.0                        15.0                 [0-15]
#
#   d_sincere_important d_intellicence_important d_funny_important  \
# 0             [16-20]                  [16-20]            [0-15]
# 1             [16-20]                  [16-20]            [0-15]
# 2             [16-20]                  [16-20]            [0-15]
# 3             [16-20]                  [16-20]            [0-15]
# 4             [16-20]                  [16-20]            [0-15]
#
#   d_ambtition_important d_shared_interests_important  attractive  sincere  \
# 0                [0-15]                       [0-15]         6.0      8.0
# 1                [0-15]                       [0-15]         6.0      8.0
# 2                [0-15]                       [0-15]         6.0      8.0
# 3                [0-15]                       [0-15]         6.0      8.0
# 4                [0-15]                       [0-15]         6.0      8.0
#
#    intelligence  funny  ambition d_attractive d_sincere d_intelligence  \
# 0           8.0    8.0       7.0        [6-8]     [6-8]          [6-8]
# 1           8.0    8.0       7.0        [6-8]     [6-8]          [6-8]
# 2           8.0    8.0       7.0        [6-8]     [6-8]          [6-8]
# 3           8.0    8.0       7.0        [6-8]     [6-8]          [6-8]
# 4           8.0    8.0       7.0        [6-8]     [6-8]          [6-8]
#
#   d_funny d_ambition  attractive_partner  sincere_partner  \
# 0   [6-8]      [6-8]                 6.0              9.0
# 1   [6-8]      [6-8]                 7.0              8.0
# 2   [6-8]      [6-8]                 5.0              8.0
# 3   [6-8]      [6-8]                 7.0              6.0
# 4   [6-8]      [6-8]                 5.0              6.0
#
#    intelligence_partner  funny_partner  ambition_partner  \
# 0                   7.0            7.0               6.0
# 1                   7.0            8.0               5.0
# 2                   9.0            8.0               5.0
# 3                   8.0            7.0               6.0
# 4                   7.0            7.0               6.0
#
#    shared_interests_partner d_attractive_partner d_sincere_partner  \
# 0                       5.0                [6-8]            [9-10]
# 1                       6.0                [6-8]             [6-8]
# 2                       7.0                [0-5]             [6-8]
# 3                       8.0                [6-8]             [6-8]
# 4                       6.0                [0-5]             [6-8]
#
#   d_intelligence_partner d_funny_partner d_ambition_partner  \
# 0                  [6-8]           [6-8]              [6-8]
# 1                  [6-8]           [6-8]              [0-5]
# 2                 [9-10]           [6-8]              [0-5]
# 3                  [6-8]           [6-8]              [6-8]
# 4                  [6-8]           [6-8]              [6-8]
#
#   d_shared_interests_partner  sports  tvsports  exercise  dining  museums  \
# 0                      [0-5]     9.0       2.0       8.0     9.0      1.0
# 1                      [6-8]     9.0       2.0       8.0     9.0      1.0
# 2                      [6-8]     9.0       2.0       8.0     9.0      1.0
# 3                      [6-8]     9.0       2.0       8.0     9.0      1.0
# 4                      [6-8]     9.0       2.0       8.0     9.0      1.0
#
#    art  hiking  gaming  clubbing  reading   tv  theater  movies  concerts  \
# 0  1.0     5.0     1.0       5.0      6.0  9.0      1.0    10.0      10.0
# 1  1.0     5.0     1.0       5.0      6.0  9.0      1.0    10.0      10.0
# 2  1.0     5.0     1.0       5.0      6.0  9.0      1.0    10.0      10.0
# 3  1.0     5.0     1.0       5.0      6.0  9.0      1.0    10.0      10.0
# 4  1.0     5.0     1.0       5.0      6.0  9.0      1.0    10.0      10.0
#
#    music  shopping  yoga d_sports d_tvsports d_exercise d_dining d_museums  \
# 0    9.0       8.0   1.0   [9-10]      [0-5]      [6-8]   [9-10]     [0-5]
# 1    9.0       8.0   1.0   [9-10]      [0-5]      [6-8]   [9-10]     [0-5]
# 2    9.0       8.0   1.0   [9-10]      [0-5]      [6-8]   [9-10]     [0-5]
# 3    9.0       8.0   1.0   [9-10]      [0-5]      [6-8]   [9-10]     [0-5]
# 4    9.0       8.0   1.0   [9-10]      [0-5]      [6-8]   [9-10]     [0-5]
#
#    d_art d_hiking d_gaming d_clubbing d_reading    d_tv d_theater d_movies  \
# 0  [0-5]    [0-5]    [0-5]      [0-5]     [6-8]  [9-10]     [0-5]   [9-10]
# 1  [0-5]    [0-5]    [0-5]      [0-5]     [6-8]  [9-10]     [0-5]   [9-10]
# 2  [0-5]    [0-5]    [0-5]      [0-5]     [6-8]  [9-10]     [0-5]   [9-10]
# 3  [0-5]    [0-5]    [0-5]      [0-5]     [6-8]  [9-10]     [0-5]   [9-10]
# 4  [0-5]    [0-5]    [0-5]      [0-5]     [6-8]  [9-10]     [0-5]   [9-10]
#
#   d_concerts d_music d_shopping d_yoga  interests_correlate  \
# 0     [9-10]  [9-10]      [6-8]  [0-5]                 0.14
# 1     [9-10]  [9-10]      [6-8]  [0-5]                 0.54
# 2     [9-10]  [9-10]      [6-8]  [0-5]                 0.16
# 3     [9-10]  [9-10]      [6-8]  [0-5]                 0.61
# 4     [9-10]  [9-10]      [6-8]  [0-5]                 0.21
#
#   d_interests_correlate  expected_happy_with_sd_people  \
# 0              [0-0.33]                            3.0
# 1              [0.33-1]                            3.0
# 2              [0-0.33]                            3.0
# 3              [0.33-1]                            3.0
# 4              [0-0.33]                            3.0
#
#    expected_num_interested_in_me  expected_num_matches  \
# 0                            2.0                   4.0
# 1                            2.0                   4.0
# 2                            2.0                   4.0
# 3                            2.0                   4.0
# 4                            2.0                   4.0
#
#   d_expected_happy_with_sd_people d_expected_num_interested_in_me  \
# 0                           [0-4]                           [0-3]
# 1                           [0-4]                           [0-3]
# 2                           [0-4]                           [0-3]
# 3                           [0-4]                           [0-3]
# 4                           [0-4]                           [0-3]
#
#   d_expected_num_matches  like  guess_prob_liked d_like d_guess_prob_liked  \
# 0                  [3-5]   7.0               6.0  [6-8]              [5-6]
# 1                  [3-5]   7.0               5.0  [6-8]              [5-6]
# 2                  [3-5]   7.0               NaN  [6-8]              [0-4]
# 3                  [3-5]   7.0               6.0  [6-8]              [5-6]
# 4                  [3-5]   6.0               6.0  [6-8]              [5-6]
#
#    met  match
# 0  0.0      0
# 1  1.0      0
# 2  1.0      1
# 3  0.0      1
# 4  0.0      1

# %%
import pandas as pd

corr_with_match = (
    df.corr(numeric_only=True)['match']
      .drop(labels=['match'], errors='ignore')
      .abs()
      .sort_values(ascending=False)
      .head(15)
)

print('15 atrybutów najsilniej skorelowanych z match:')
print(corr_with_match)
# Out:
# 15 atrybutów najsilniej skorelowanych z match:
# like                             0.305723
# funny_o                          0.277700
# funny_partner                    0.277545
# shared_interests_o               0.270840
# shared_interests_partner         0.270679
# attractive_o                     0.260837
# attractive_partner               0.260676
# guess_prob_liked                 0.255531
# intelligence_partner             0.169532
# intelligence_o                   0.169448
# sinsere_o                        0.164523
# sincere_partner                  0.164449
# expected_num_interested_in_me    0.143755
# ambition_partner                 0.140042
# ambitous_o                       0.139927
# Name: match, dtype: float64

# %%
import matplotlib.pyplot as plt
import pandas as pd


top5_features = corr_with_match.head(5).index
corr_full = df.corr(numeric_only=True)['match']

print('5 atrybutów najsilniej skorelowanych z match (po module):')
print(corr_with_match.head(5))

# Rozkład match: przywrócony do wersji ogólnej (bez wymuszania 0/1).
match_series = pd.to_numeric(df['match'], errors='coerce')
if match_series.nunique(dropna=True) <= 20:
    # przy wielu niskich wartościach dyskretnych pokażemy słupki dla każdego unikalnego wyniku
    match_series.value_counts(dropna=True).sort_index().plot(kind='bar', color='steelblue')
    plt.xticks(rotation=0)
else:
    match_series.hist(bins=30, alpha=0.85, color='steelblue')

plt.title('Rozkład atrybutu match')
plt.xlabel('match')
plt.ylabel('Liczba rekordów')
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# 5 atrybutów najsilniej skorelowanych z match (po module):
# like                        0.305723
# funny_o                     0.277700
# funny_partner               0.277545
# shared_interests_o          0.270840
# shared_interests_partner    0.270679
# Name: match, dtype: float64

# %% [markdown]
# ### Zadanie 1.2

# %%
print(Speed_dating.DESCR)
# Out:
# **Author**: Ray Fisman and Sheena Iyengar
# **Source**: [Columbia Business School](http://www.stat.columbia.edu/~gelman/arm/examples/speed.dating/) - 2004
# **Please cite**: None
#
# This data was gathered from participants in experimental speed dating events from 2002-2004. During the events, the attendees would have a four-minute "first date" with every other participant of the opposite sex. At the end of their four minutes, participants were asked if they would like to see their date again. They were also asked to rate their date on six attributes: Attractiveness, Sincerity, Intelligence, Fun, Ambition, and Shared Interests. The dataset also includes questionnaire data gathered from participants at different points in the process. These fields include: demographics, dating habits, self-perception across key attributes, beliefs on what others find valuable in a mate, and lifestyle information.
#
# ### Attribute Information
# ```
#  * gender: Gender of self
#  * age: Age of self
#  * age_o: Age of partner
#  * d_age: Difference in age
#  * race: Race of self
#  * race_o: Race of partner
#  * samerace: Whether the two persons have the same race or not.
#  * importance_same_race: How important is it that partner is of same race?
#  * importance_same_religion: How important is it that partner has same religion?
#  * field: Field of study
#  * pref_o_attractive: How important does partner rate attractiveness
#  * pref_o_sinsere: How important does partner rate sincerity
#  * pref_o_intelligence: How important does partner rate intelligence
#  * pref_o_funny: How important does partner rate being funny
#  * pref_o_ambitious: How important does partner rate ambition
#  * pref_o_shared_interests: How important does partner rate having shared interests
#  * attractive_o: Rating by partner (about me) at night of event on attractiveness
#  * sincere_o: Rating by partner (about me) at night of event on sincerity
#  * intelligence_o: Rating by partner (about me) at night of event on intelligence
#  * funny_o: Rating by partner (about me) at night of event on being funny
#  * ambitous_o: Rating by partner (about me) at night of event on being ambitious
#  * shared_interests_o: Rating by partner (about me) at night of event on shared interest
#  * attractive_important: What do you look for in a partner - attractiveness
#  * sincere_important: What do you look for in a partner - sincerity
#  * intellicence_important: What do you look for in a partner - intelligence
#  * funny_important: What do you look for in a partner - being funny
#  * ambtition_important: What do you look for in a partner - ambition
#  * shared_interests_important: What do you look for in a partner - shared interests
#  * attractive: Rate yourself - attractiveness
#  * sincere: Rate yourself - sincerity
#  * intelligence: Rate yourself - intelligence
#  * funny: Rate yourself - being funny
#  * ambition: Rate yourself - ambition
#  * attractive_partner: Rate your partner - attractiveness
#  * sincere_partner: Rate your partner - sincerity
#  * intelligence_partner: Rate your partner - intelligence
#  * funny_partner: Rate your partner - being funny
#  * ambition_partner: Rate your partner - ambition
#  * shared_interests_partner: Rate your partner - shared interests
#  * sports: Your own interests [1-10]
#  * tvsports
#  * exercise
#  * dining
#  * museums
#  * art
#  * hiking
#  * gaming
#  * clubbing
#  * reading
#  * tv
#  * theater
#  * movies
#  * concerts
#  * music
#  * shopping
#  * yoga
#  * interests_correlate: Correlation between participant’s and partner’s ratings of interests.
#  * expected_happy_with_sd_people: How happy do you expect to be with the people you meet during the speed-dating event?
#  * expected_num_interested_in_me: Out of the 20 people you will meet, how many do you expect will be interested in dating you?
#  * expected_num_matches: How many matches do you expect to get?
#  * like: Did you like your partner?
#  * guess_prob_liked: How likely do you think it is that your partner likes you?
#  * met: Have you met your partner before?
#  * decision: Decision at night of event.
#  * decision_o: Decision of partner at night of event.
#  * match: Match (yes/no)
# ```
#
# ### Relevant paper
#
# Raymond Fisman; Sheena S. Iyengar; Emir Kamenica; Itamar Simonson.
# Gender Differences in Mate Selection: Evidence From a Speed Dating Experiment.
# The Quarterly Journal of Economics, Volume 121, Issue 2, 1 May 2006, Pages 673–697,
# [https://doi.org/10.1162/qjec.2006.121.2.673](https://doi.org/10.1162/qjec.2006.121.2.673)
#
# Downloaded from openml.org.

# %%
import pandas as pd
right_columns = ['gender', 'age', 'race', 'importance_same_race',
       'importance_same_religion',
       'field', 'attractive_important',
       'sincere_important', 'intellicence_important', 'funny_important',
       'ambtition_important', 'shared_interests_important',
       'attractive',
       'sincere', 'intelligence', 'funny', 'ambition', 'sports',
       'tvsports', 'exercise', 'dining', 'museums', 'art', 'hiking', 'gaming',
       'clubbing', 'reading', 'tv', 'theater', 'movies', 'concerts', 'music',
       'shopping', 'yoga', 'match']

df = df[right_columns].copy()

# %%
profile_features = ['gender', 'age', 'race']
df['user_id'] = df.groupby(profile_features, dropna=False).ngroup()


df = df.dropna(subset=['match'])
df['match'] = df['match'].astype(int)

user_counts = df['user_id'].value_counts()
valid_users = user_counts[user_counts > 5].index
df_valid = df[df['user_id'].isin(valid_users)]

test_indices = df_valid.groupby('user_id').sample(n=5, random_state=42).index
train_indices = df.index.difference(test_indices)

X = df.drop(columns=['match'])
y = df['match']

X_train = X.loc[train_indices].copy()
y_train = y.loc[train_indices].copy()
X_test = X.loc[test_indices].copy()
y_test = y.loc[test_indices].copy()

X_train_id = X_train.pop('user_id')
X_test_id = X_test.pop('user_id')

# %% [markdown]
# ### Zadanie 1.3: Model Bazowy i Wizualizacja Problemu

# %%
from sklearn.impute import SimpleImputer
from sklearn.dummy import DummyClassifier
from sklearn.linear_model import LogisticRegression
from imblearn.metrics import classification_report_imbalanced


X_train_num = X_train.select_dtypes(include=np.number)
X_test_num = X_test.select_dtypes(include=np.number)

imputer_num = SimpleImputer(strategy='median')
X_train_imputed = imputer_num.fit_transform(X_train_num)
X_test_imputed = imputer_num.transform(X_test_num)

print("--- Dummy Prior (Większościowy) ---")
dummy_prior = DummyClassifier(strategy='prior')
dummy_prior.fit(X_train_imputed, y_train)
print(classification_report_imbalanced(y_test, dummy_prior.predict(X_test_imputed)))

print("--- Dummy Uniform (Losowy) ---")
dummy_uniform = DummyClassifier(strategy='uniform', random_state=42)
dummy_uniform.fit(X_train_imputed, y_train)
print(classification_report_imbalanced(y_test, dummy_uniform.predict(X_test_imputed)))

print("--- Logistic Regression ---")
lr = LogisticRegression(max_iter=1000, random_state=42)
lr.fit(X_train_imputed, y_train)
y_pred_lr = lr.predict(X_test_imputed)
print(classification_report_imbalanced(y_test, y_pred_lr))
# Out:
# --- Dummy Prior (Większościowy) ---
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.83      1.00      0.00      0.91      0.00      0.00       526
#           1       0.00      0.00      1.00      0.00      0.00      0.00       104
#
# avg / total       0.70      0.83      0.17      0.76      0.00      0.00       630
#
# --- Dummy Uniform (Losowy) ---
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.85      0.49      0.57      0.62      0.53      0.28       526
#           1       0.18      0.57      0.49      0.27      0.53      0.28       104
#
# avg / total       0.74      0.50      0.55      0.56      0.53      0.28       630
#
# --- Logistic Regression ---
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.83      1.00      0.00      0.91      0.00      0.00       526
#           1       0.00      0.00      1.00      0.00      0.00      0.00       104
#
# avg / total       0.70      0.83      0.17      0.76      0.00      0.00       630
# /Users/tymon/Documents/sem2/edukacja_szyn/.venv/lib/python3.14/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Users/tymon/Documents/sem2/edukacja_szyn/.venv/lib/python3.14/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# ### Zadanie 1.4: Techniki Resamplingu

# %%
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.combine import SMOTEENN
from imblearn.pipeline import Pipeline as ImbPipeline

idx = np.random.choice(len(X_train_imputed), 1500, replace=False)
X_sample, y_sample = X_train_imputed[idx], y_train.iloc[idx]
tsne = TSNE(n_components=2, random_state=42)
X_tsne = tsne.fit_transform(X_sample)

plt.figure(figsize=(6, 4))
plt.scatter(X_tsne[y_sample == 0, 0], X_tsne[y_sample == 0, 1], label='0', alpha=0.5, s=10)
plt.scatter(X_tsne[y_sample == 1, 0], X_tsne[y_sample == 1, 1], label='1', alpha=0.5, s=10, c='red')
plt.title("t-SNE (1500 próbek) przed resamplingiem")
plt.legend()
plt.show()

smote = SMOTE(random_state=42)
X_smote, y_smote = smote.fit_resample(X_train_imputed, y_train)

resample_pipe = ImbPipeline([
    ('under', RandomUnderSampler(sampling_strategy=0.5, random_state=42)),
    ('smote', SMOTE(random_state=42)),
    ('model', LogisticRegression(max_iter=1000))
])
resample_pipe.fit(X_train_imputed, y_train)
print("--- Pipeline (UnderSampler + SMOTE) ---")
print(classification_report_imbalanced(y_test, resample_pipe.predict(X_test_imputed)))

sme = SMOTEENN(random_state=42)
pipe_sme = ImbPipeline([('sme', sme), ('model', LogisticRegression(max_iter=1000))])
pipe_sme.fit(X_train_imputed, y_train)
print("--- SMOTE+ENN ---")
print(classification_report_imbalanced(y_test, pipe_sme.predict(X_test_imputed)))
# Out:
# --- Pipeline (UnderSampler + SMOTE) ---
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.87      0.62      0.55      0.73      0.58      0.34       526
#           1       0.22      0.55      0.62      0.32      0.58      0.34       104
#
# avg / total       0.77      0.61      0.56      0.66      0.58      0.34       630
#
# --- SMOTE+ENN ---
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.84      0.97      0.04      0.90      0.19      0.04       526
#           1       0.21      0.04      0.97      0.07      0.19      0.03       104
#
# avg / total       0.73      0.82      0.19      0.76      0.19      0.04       630

# %% [markdown]
# ### Zadanie 1.5: Modele Ensemble dla Danych Niezbalansowanych

# %%
from imblearn.ensemble import BalancedRandomForestClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import RocCurveDisplay, PrecisionRecallDisplay

print("--- BalancedRandomForestClassifier ---")
brf = BalancedRandomForestClassifier(n_estimators=100, random_state=42)
brf.fit(X_train_imputed, y_train)
print(classification_report_imbalanced(y_test, brf.predict(X_test_imputed)))

print("--- RandomForestClassifier (class_weight='balanced') ---")
rf_bal = RandomForestClassifier(n_estimators=100, class_weight='balanced', random_state=42)
rf_bal.fit(X_train_imputed, y_train)
print(classification_report_imbalanced(y_test, rf_bal.predict(X_test_imputed)))

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))
RocCurveDisplay.from_estimator(brf, X_test_imputed, y_test, ax=ax1, name="Balanced RF")
RocCurveDisplay.from_estimator(rf_bal, X_test_imputed, y_test, ax=ax1, name="RF (class_weight)")
ax1.set_title("Krzywa ROC")

PrecisionRecallDisplay.from_estimator(brf, X_test_imputed, y_test, ax=ax2, name="Balanced RF")
PrecisionRecallDisplay.from_estimator(rf_bal, X_test_imputed, y_test, ax=ax2, name="RF (class_weight)")
ax2.set_title("Krzywa Precision-Recall")
plt.show()
# Out:
# --- BalancedRandomForestClassifier ---
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.89      0.66      0.59      0.75      0.62      0.39       526
#           1       0.25      0.59      0.66      0.35      0.62      0.38       104
#
# avg / total       0.78      0.64      0.60      0.69      0.62      0.39       630
#
# --- RandomForestClassifier (class_weight='balanced') ---
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.88      0.71      0.53      0.79      0.61      0.39       526
#           1       0.27      0.53      0.71      0.36      0.61      0.37       104
#
# avg / total       0.78      0.68      0.56      0.72      0.61      0.38       630

# %% [markdown]
# ## CZĘŚĆ 2: Kalibracja Modeli i Macierz Kosztów
# ### Zadanie 2.1: Ewaluacja w kontekście aplikacji

# %%
import pandas as pd

y_prob = brf.predict_proba(X_test_imputed)[:, 1]

results = pd.DataFrame({
    'user_id': X_test_id.values,
    'true_match': y_test.values,
    'prob': y_prob
})
results = results.sort_values(by=['user_id', 'prob'], ascending=[True, False])

def calculate_ranking_metrics(df_user, k=3):
    matches = np.where(df_user['true_match'] == 1)[0]
    mrr = 1.0 / (matches[0] + 1) if len(matches) > 0 else 0.0
    top_k = df_user.head(k)
    prec_at_k = top_k['true_match'].mean() if len(top_k) > 0 else 0.0
    return pd.Series({'mrr': mrr, f'prec@{k}': prec_at_k})

metrics_per_user = results.groupby('user_id').apply(calculate_ranking_metrics)
print("Średnie metryki rekomendacyjne dla systemu:")
print(metrics_per_user.mean())
# Out:
# Średnie metryki rekomendacyjne dla systemu:
# mrr       0.362963
# prec@3    0.198413
# dtype: float64

# %% [markdown]
# ### Zadanie 2.2: Strategia "Model Romantyczny"

# %%
threshold_romantic = 0.2
y_pred_romantic = (y_prob >= threshold_romantic).astype(int)

from sklearn.metrics import recall_score, precision_score, f1_score
print(f"--- Model Romantyczny (threshold={threshold_romantic}) ---")
print(f"Recall:    {recall_score(y_test, y_pred_romantic):.4f}")
print(f"Precision: {precision_score(y_test, y_pred_romantic):.4f}")
print(f"F1-Score:  {f1_score(y_test, y_pred_romantic):.4f}")
# Out:
# --- Model Romantyczny (threshold=0.2) ---
# Recall:    0.8462
# Precision: 0.1901
# F1-Score:  0.3104

# %% [markdown]
# ### Zadanie 2.3: Strategia "Model Biznesowy"

# %%
def calc_business_profit(y_true, y_pred):
    TP = ((y_true == 1) & (y_pred == 1)).sum()
    TN = ((y_true == 0) & (y_pred == 0)).sum()
    FP = ((y_true == 0) & (y_pred == 1)).sum()
    FN = ((y_true == 1) & (y_pred == 0)).sum()
    return (TP * 5) + (FP * -2) + (FN * -1)

thresholds = np.linspace(0, 1, 100)
profits = [calc_business_profit(y_test, (y_prob >= t).astype(int)) for t in thresholds]

best_idx = np.argmax(profits)
threshold_business = thresholds[best_idx]
max_profit = profits[best_idx]

print(f"Najlepszy próg biznesowy: {threshold_business:.2f}")
print(f"Maksymalny zysk biznesowy: {max_profit}")

y_pred_business = (y_prob >= threshold_business).astype(int)
# Out:
# Najlepszy próg biznesowy: 0.72
# Maksymalny zysk biznesowy: -36

# %% [markdown]
# ### Zadanie 2.4: Podsumowanie Wyników

# %%
business_profit_romantic = calc_business_profit(y_test, y_pred_romantic)
business_profit_business = max_profit
business_profit_baseline = calc_business_profit(y_test, brf.predict(X_test_imputed))

summary_data = {
    'Strategia': ['Romantyczna', 'Biznesowa', 'Domyślna (0.5)'],
    'Threshold': [threshold_romantic, threshold_business, 0.5],
    'Recall': [
        recall_score(y_test, y_pred_romantic),
        recall_score(y_test, y_pred_business),
        recall_score(y_test, brf.predict(X_test_imputed))
    ],
    'Precision': [
        precision_score(y_test, y_pred_romantic, zero_division=0),
        precision_score(y_test, y_pred_business, zero_division=0),
        precision_score(y_test, brf.predict(X_test_imputed), zero_division=0)
    ],
    'Zysk Biznesowy': [business_profit_romantic, business_profit_business, business_profit_baseline]
}

display(pd.DataFrame(summary_data))
# Out:
#         Strategia  Threshold    Recall  Precision  Zysk Biznesowy
# 0     Romantyczna   0.200000  0.846154   0.190065            -326
# 1       Biznesowa   0.717172  0.259615   0.364865             -36
# 2  Domyślna (0.5)   0.500000  0.586538   0.252066            -100

# %% [markdown]
# ### Wnioski
# Model biznesowy ustala odpowiedni threshold, który balansuje liczbę poprawnych
# dopasowań w taki sposób, aby odsiać drogie pomyłki (FP) i zoptymalizować realny dochód/zadowolenie.
# Model romantyczny zgadza się na stratę finansową za cenę wysokiego odsetka dopasowań.
